-- %% [markdown]
-- # [DBRodrigo]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DBRodrigo]    Script Date: 25/08/2024 02:22:30 p. m. ******/
CREATE DATABASE [DBRodrigo]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DBRodrigo', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DBRodrigo.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DBRodrigo_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DBRodrigo_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DBRodrigo] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DBRodrigo].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DBRodrigo] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DBRodrigo] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DBRodrigo] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DBRodrigo] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DBRodrigo] SET ARITHABORT OFF 
GO
ALTER DATABASE [DBRodrigo] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DBRodrigo] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DBRodrigo] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DBRodrigo] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DBRodrigo] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DBRodrigo] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DBRodrigo] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DBRodrigo] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DBRodrigo] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DBRodrigo] SET  ENABLE_BROKER 
GO
ALTER DATABASE [DBRodrigo] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DBRodrigo] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DBRodrigo] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DBRodrigo] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DBRodrigo] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DBRodrigo] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DBRodrigo] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DBRodrigo] SET RECOVERY FULL 
GO
ALTER DATABASE [DBRodrigo] SET  MULTI_USER 
GO
ALTER DATABASE [DBRodrigo] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DBRodrigo] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DBRodrigo] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DBRodrigo] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DBRodrigo] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DBRodrigo] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'DBRodrigo', N'ON'
GO
ALTER DATABASE [DBRodrigo] SET QUERY_STORE = ON
GO
ALTER DATABASE [DBRodrigo] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Articulos]

-- %%
USE [DBRodrigo]
GO

-- %%
/****** Object:  Table [dbo].[Articulos]    Script Date: 25/08/2024 02:22:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Articulos](
	[ArticuloID] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [nvarchar](20) NOT NULL,
	[Descripcion] [nvarchar](100) NOT NULL,
	[Precio] [decimal](10, 2) NOT NULL,
	[Imagen] [varbinary](max) NULL,
	[Stock] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ArticuloID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ArticuloTienda]

-- %%
/****** Object:  Table [dbo].[ArticuloTienda]    Script Date: 25/08/2024 02:22:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ArticuloTienda](
	[ArticuloTiendaID] [int] IDENTITY(1,1) NOT NULL,
	[ArticuloID] [int] NOT NULL,
	[TiendaID] [int] NOT NULL,
	[Fecha] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ArticuloTiendaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ClienteArticulo]

-- %%
/****** Object:  Table [dbo].[ClienteArticulo]    Script Date: 25/08/2024 02:22:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ClienteArticulo](
	[ClienteArticuloID] [int] IDENTITY(1,1) NOT NULL,
	[ClienteID] [int] NOT NULL,
	[ArticuloID] [int] NOT NULL,
	[Fecha] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ClienteArticuloID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 25/08/2024 02:22:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[ClienteID] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](50) NOT NULL,
	[Apellidos] [nvarchar](50) NOT NULL,
	[Direccion] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ClienteID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tienda]

-- %%
/****** Object:  Table [dbo].[Tienda]    Script Date: 25/08/2024 02:22:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tienda](
	[TiendaID] [int] IDENTITY(1,1) NOT NULL,
	[Sucursal] [nvarchar](50) NOT NULL,
	[Direccion] [nvarchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[TiendaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__ArticuloT__Artic__4F7CD00D]

-- %%
ALTER TABLE [dbo].[ArticuloTienda]  WITH CHECK ADD FOREIGN KEY([ArticuloID])
REFERENCES [dbo].[Articulos] ([ArticuloID])
GO

-- %% [markdown]
-- # [FK__ArticuloT__Tiend__5070F446]

-- %%
ALTER TABLE [dbo].[ArticuloTienda]  WITH CHECK ADD FOREIGN KEY([TiendaID])
REFERENCES [dbo].[Tienda] ([TiendaID])
GO

-- %% [markdown]
-- # [FK__ClienteAr__Artic__5441852A]

-- %%
ALTER TABLE [dbo].[ClienteArticulo]  WITH CHECK ADD FOREIGN KEY([ArticuloID])
REFERENCES [dbo].[Articulos] ([ArticuloID])
GO

-- %% [markdown]
-- # [FK__ClienteAr__Clien__534D60F1]

-- %%
ALTER TABLE [dbo].[ClienteArticulo]  WITH CHECK ADD FOREIGN KEY([ClienteID])
REFERENCES [dbo].[Clientes] ([ClienteID])
GO

-- %% [markdown]
-- # [DBRodrigo]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DBRodrigo] SET  READ_WRITE 
GO
